# %% [markdown]
# Preprocessing - **SparsePCA** (component=1)
# Algorithm - **Sparse Classification**
# Feature - **Real + Imaginary**

# %%
import numpy as np
from sklearn.linear_model import OrthogonalMatchingPursuit
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import SparsePCA

np.set_printoptions(threshold=np.inf)
np.set_printoptions(suppress=True)

n_comp = 20
alice_channel = 3  # Channel 3 is ALICE (legitimate)
eve_channel = 6  # Channel 6 is EVE (illegitimate)

measurement = np.load('../../../dataset/meas_symm_1.npz', allow_pickle=False)
header, data = measurement['header'], measurement['data']
data_cir = data['cirs'][:3000]
trainCIR, testCIR = train_test_split(data_cir, test_size=0.2, random_state=42)

# %%
# ---------------------------------------- Preprocessing ----------------------------------------
def getRealImaginaryParts(cirs):
    real = cirs[:, :, 0]
    imag = cirs[:, :, 1]
    return real, imag

def apply_sparse_pca(data, n_components):

    # data : (1600, 251, 2)
    reshaped_data = data.reshape(data.shape[0], -1) # (1600, 502)
    
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(reshaped_data)
    
    spca = SparsePCA(n_components=n_components, random_state=42)
    data_spca = spca.fit_transform(data_scaled) # (1600, 2)
    
    return data_spca, scaler, spca

# -------------- Training ----------------
# Feature Extraction
train_alice_cirs = trainCIR[:, alice_channel, :, :]  
train_eve_cirs = trainCIR[:, eve_channel, :, :]
train_cirs = np.vstack((train_alice_cirs, train_eve_cirs)) 
train_cirs_spca, scaler, spca = apply_sparse_pca(train_cirs, n_components=n_comp)

# Labels
train_alice_labels = np.zeros(train_alice_cirs.shape[0])  # Label '0' for Alice.
train_eve_labels = np.ones(train_eve_cirs.shape[0])       # Label '1' for Eve.
train_labels = np.hstack((train_alice_labels, train_eve_labels))

# Atoms
train_atoms = train_cirs_spca

# Dictionary 
D = train_atoms.T
print(f'Dictionary : {D.shape}')


# -------------- Testing ----------------
# Feature Extraction
test_alice_cirs = testCIR[:, alice_channel, :, :]
test_eve_cirs = testCIR[:, eve_channel, :, :]
test_cirs = np.vstack((test_alice_cirs, test_eve_cirs))  # (samples, 251, 2)

# Reshape
reshaped_test_cirs = test_cirs.reshape(test_cirs.shape[0], -1)  # (samples, 251*2)
# Scaling
test_cirs_scaled = scaler.transform(reshaped_test_cirs)
# Sparse PCA
test_cirs_spca = spca.transform(test_cirs_scaled)  # (samples, n_components)

# Labels
alice_test_labels = np.zeros(test_alice_cirs.shape[0])  # Label '0' for Alice.
eve_test_labels = np.ones(test_eve_cirs.shape[0])       # Label '1' for Eve.
test_labels = np.hstack((alice_test_labels, eve_test_labels))

# test Atoms
test_atoms = test_cirs_spca
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 25
#      23 train_eve_cirs = trainCIR[:, eve_channel, :, :]
#      24 train_cirs = np.vstack((train_alice_cirs, train_eve_cirs))
# ---> 25 train_cirs_spca, scaler, spca = apply_sparse_pca(train_cirs, n_components=n_comp)
#      27 # Labels
#      28 train_alice_labels = np.zeros(train_alice_cirs.shape[0])  # Label '0' for Alice.
#
# Cell In[2], line 16, in apply_sparse_pca(data, n_components)
#      13 data_scaled = scaler.fit_transform(reshaped_data)
#      15 spca = SparsePCA(n_components=n_components, random_state=42)
# ---> 16 data_spca = spca.fit_transform(data_scaled) # (1600, 2)
#      18 return data_spca, scaler, spca
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/decomposition/_sparse_pca.py:91, in _BaseSparsePCA.fit(self, X, y)
#      88 else:
#      89     n_components = self.n_components
# ---> 91 return self._fit(X, n_components, random_state)
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/decomposition/_sparse_pca.py:313, in SparsePCA._fit(self, X, n_components, random_state)
#     311 code_init = self.V_init.T if self.V_init is not None else None
#     312 dict_init = self.U_init.T if self.U_init is not None else None
# --> 313 code, dictionary, E, self.n_iter_ = dict_learning(
#     314     X.T,
#     315     n_components,
#     316     alpha=self.alpha,
#     317     tol=self.tol,
#     318     max_iter=self.max_iter,
#     319     method=self.method,
#     320     n_jobs=self.n_jobs,
#     321     verbose=self.verbose,
#     322     random_state=random_state,
#     323     code_init=code_init,
#     324     dict_init=dict_init,
#     325     return_n_iter=True,
#     326 )
#     327 # flip eigenvectors' sign to enforce deterministic output
#     328 code, dictionary = svd_flip(code, dictionary, u_based_decision=True)
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/decomposition/_dict_learning.py:1078, in dict_learning(X, n_components, alpha, max_iter, tol, method, n_jobs, dict_init, code_init, callback, verbose, random_state, return_n_iter, positive_dict, positive_code, method_max_iter)
#     929 """Solve a dictionary learning matrix factorization problem.
#     930
#     931 Finds the best dictionary and the corresponding sparse code for
#    (...)
#    1060 0.01...
#    1061 """
#    1062 estimator = DictionaryLearning(
#    1063     n_components=n_components,
#    1064     alpha=alpha,
#    (...)
#    1076     transform_max_iter=method_max_iter,
#    1077 ).set_output(transform="default")
# -> 1078 code = estimator.fit_transform(X)
#    1079 if return_n_iter:
#    1080     return (
#    1081         code,
#    1082         estimator.components_,
#    1083         estimator.error_,
#    1084         estimator.n_iter_,
#    1085     )
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/decomposition/_dict_learning.py:1681, in DictionaryLearning.fit_transform(self, X, y)
#    1678 else:
#    1679     n_components = self.n_components
# -> 1681 V, U, E, self.n_iter_ = _dict_learning(
#    1682     X,
#    1683     n_components,
#    1684     alpha=self.alpha,
#    1685     tol=self.tol,
#    1686     max_iter=self.max_iter,
#    1687     method=method,
#    1688     method_max_iter=self.transform_max_iter,
#    1689     n_jobs=self.n_jobs,
#    1690     code_init=self.code_init,
#    1691     dict_init=self.dict_init,
#    1692     callback=self.callback,
#    1693     verbose=self.verbose,
#    1694     random_state=random_state,
#    1695     return_n_iter=True,
#    1696     positive_dict=self.positive_dict,
#    1697     positive_code=self.positive_code,
#    1698 )
#    1699 self.components_ = U
#    1700 self.error_ = E
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/decomposition/_dict_learning.py:620, in _dict_learning(X, n_components, alpha, max_iter, tol, method, n_jobs, dict_init, code_init, callback, verbose, random_state, return_n_iter, positive_dict, positive_code, method_max_iter)
#     614     print(
#     615         "Iteration % 3i (elapsed time: % 3is, % 4.1fmn, current cost % 7.3f)"
#     616         % (ii, dt, dt / 60, current_cost)
#     617     )
#     619 # Update code
# --> 620 code = sparse_encode(
#     621     X,
#     622     dictionary,
#     623     algorithm=method,
#     624     alpha=alpha,
#     625     init=code,
#     626     n_jobs=n_jobs,
#     627     positive=positive_code,
#     628     max_iter=method_max_iter,
#     629     verbose=verbose,
#     630 )
#     632 # Update dictionary in place
#     633 _update_dict(
#     634     dictionary,
#     635     X,
#    (...)
#     639     positive=positive_dict,
#     640 )
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/decomposition/_dict_learning.py:377, in sparse_encode(X, dictionary, gram, cov, algorithm, n_nonzero_coefs, alpha, copy_cov, init, max_iter, n_jobs, check_input, verbose, positive)
#     370     raise ValueError(
#     371         "Dictionary and X have different numbers of features:"
#     372         "dictionary.shape: {} X.shape{}".format(dictionary.shape, X.shape)
#     373     )
#     375 _check_positive_coding(algorithm, positive)
# --> 377 return _sparse_encode(
#     378     X,
#     379     dictionary,
#     380     gram=gram,
#     381     cov=cov,
#     382     algorithm=algorithm,
#     383     n_nonzero_coefs=n_nonzero_coefs,
#     384     alpha=alpha,
#     385     copy_cov=copy_cov,
#     386     init=init,
#     387     max_iter=max_iter,
#     388     n_jobs=n_jobs,
#     389     verbose=verbose,
#     390     positive=positive,
#     391 )
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/decomposition/_dict_learning.py:432, in _sparse_encode(X, dictionary, gram, cov, algorithm, n_nonzero_coefs, alpha, copy_cov, init, max_iter, n_jobs, verbose, positive)
#     429     cov = np.dot(dictionary, X.T)
#     431 if effective_n_jobs(n_jobs) == 1 or algorithm == "threshold":
# --> 432     code = _sparse_encode_precomputed(
#     433         X,
#     434         dictionary,
#     435         gram=gram,
#     436         cov=cov,
#     437         algorithm=algorithm,
#     438         regularization=regularization,
#     439         copy_cov=copy_cov,
#     440         init=init,
#     441         max_iter=max_iter,
#     442         verbose=verbose,
#     443         positive=positive,
#     444     )
#     445     return code
#     447 # Enter parallel code block
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/decomposition/_dict_learning.py:135, in _sparse_encode_precomputed(X, dictionary, gram, cov, algorithm, regularization, copy_cov, init, max_iter, verbose, positive)
#     124     # Not passing in verbose=max(0, verbose-1) because Lars.fit already
#     125     # corrects the verbosity level.
#     126     lasso_lars = LassoLars(
#     127         alpha=alpha,
#     128         fit_intercept=False,
#    (...)
#     133         max_iter=max_iter,
#     134     )
# --> 135     lasso_lars.fit(dictionary.T, X.T, Xy=cov)
#     136     new_code = lasso_lars.coef_
#     137 finally:
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/linear_model/_least_angle.py:1198, in Lars.fit(self, X, y, Xy)
#    1195     noise = rng.uniform(high=self.jitter, size=len(y))
#    1196     y = y + noise
# -> 1198 self._fit(
#    1199     X,
#    1200     y,
#    1201     max_iter=max_iter,
#    1202     alpha=alpha,
#    1203     fit_path=self.fit_path,
#    1204     Xy=Xy,
#    1205 )
#    1207 return self
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/linear_model/_least_angle.py:1136, in Lars._fit(self, X, y, max_iter, alpha, fit_path, Xy)
#    1134 for k in range(n_targets):
#    1135     this_Xy = None if Xy is None else Xy[:, k]
# -> 1136     alphas, _, self.coef_[k], n_iter_ = lars_path(
#    1137         X,
#    1138         y[:, k],
#    1139         Gram=Gram,
#    1140         Xy=this_Xy,
#    1141         copy_X=self.copy_X,
#    1142         copy_Gram=True,
#    1143         alpha_min=alpha,
#    1144         method=self.method,
#    1145         verbose=max(0, self.verbose - 1),
#    1146         max_iter=max_iter,
#    1147         eps=self.eps,
#    1148         return_path=False,
#    1149         return_n_iter=True,
#    1150         positive=self.positive,
#    1151     )
#    1152     self.alphas_.append(alphas)
#    1153     self.n_iter_.append(n_iter_)
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/linear_model/_least_angle.py:218, in lars_path(X, y, Xy, Gram, max_iter, alpha_min, method, copy_X, eps, copy_Gram, verbose, return_path, return_n_iter, positive)
#     213 if X is None and Gram is not None:
#     214     raise ValueError(
#     215         "X cannot be None if Gram is not None"
#     216         "Use lars_path_gram to avoid passing X and y."
#     217     )
# --> 218 return _lars_path_solver(
#     219     X=X,
#     220     y=y,
#     221     Xy=Xy,
#     222     Gram=Gram,
#     223     n_samples=None,
#     224     max_iter=max_iter,
#     225     alpha_min=alpha_min,
#     226     method=method,
#     227     copy_X=copy_X,
#     228     eps=eps,
#     229     copy_Gram=copy_Gram,
#     230     verbose=verbose,
#     231     return_path=return_path,
#     232     return_n_iter=return_n_iter,
#     233     positive=positive,
#     234 )
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/sklearn/linear_model/_least_angle.py:708, in _lars_path_solver(X, y, Xy, Gram, n_samples, max_iter, alpha_min, method, copy_X, eps, copy_Gram, verbose, return_path, return_n_iter, positive)
#     706 # Update the cholesky decomposition for the Gram matrix
#     707 if n_active:
# --> 708     linalg.solve_triangular(
#     709         L[:n_active, :n_active],
#     710         L[n_active, :n_active],
#     711         trans=0,
#     712         lower=1,
#     713         overwrite_b=True,
#     714         **SOLVE_TRIANGULAR_ARGS,
#     715     )
#     717 v = np.dot(L[n_active, :n_active], L[n_active, :n_active])
#     718 diag = max(np.sqrt(np.abs(c - v)), eps)
#
# File ~/anaconda3/envs/CRKG/lib/python3.12/site-packages/scipy/linalg/_basic.py:264, in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, check_finite)
#     259         x = x.ravel()
#     261     return x
# --> 264 def solve_triangular(a, b, trans=0, lower=False, unit_diagonal=False,
#     265                      overwrite_b=False, check_finite=True):
#     266     """
#     267     Solve the equation `a x = b` for `x`, assuming a is a triangular matrix.
#     268
#    (...)
#     330
#     331     """
#     333     a1 = _asarray_validated(a, check_finite=check_finite)
#
# KeyboardInterrupt:

# %%
# ---------------------------------------- Sparse Classification ----------------------------------------
# Sparse Coding Function

# Sparse Coefficients
def find_sparse_coefficients(tSample, D, n_nonzero_coefs=10):
    omp = OrthogonalMatchingPursuit(n_nonzero_coefs=n_nonzero_coefs)
    omp.fit(D, tSample)
    return omp.coef_

# Calculate Residuals for Each Class
def calculate_residual(tSample, coefficients, class_indices, D):
    coef_class = np.zeros_like(coefficients)
    coef_class[class_indices] = coefficients[class_indices]  # Keep only coefficients for the specified class
    reconstructed_signal = D @ coef_class
    residual = np.linalg.norm(tSample - reconstructed_signal)
    return residual

# Classification Function
def classify_signal(tSample, D, trainLabel):
    
    coefficients = find_sparse_coefficients(tSample, D)
    
    residuals = []

    unique_classes = np.unique(trainLabel) # 0 and 1
    for class_label in unique_classes:
        class_indices = np.where(trainLabel == class_label)[0]  # Indices of columns in D belonging to this class
        residual = calculate_residual(tSample, coefficients, class_indices, D)
        residuals.append(residual)

    min_residual_index = np.argmin(residuals)
    predicted_class = unique_classes[min_residual_index]
    
    return predicted_class

predictions = []

# Classifying Test Data
for testSample in test_atoms:
    predicted_class = classify_signal(testSample, D, train_labels)
    predictions.append(predicted_class)

predictions = np.array(predictions)

# %%
# ---------------------------------------- Evaluation ----------------------------------------
accuracy = np.mean(predictions == test_labels)
print(f"Classification Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
print(f"\nTotal testing channel: {test_labels.shape}")

tn, fp, fn, tp = confusion_matrix(test_labels, predictions, labels=[0, 1]).ravel()

print(f"tp: {tp}")
print(f"tn: {tn}")
print(f"fp: {fp}")
print(f"fn: {fn}")

# Missed Detection Rate (MDR)
MDR = fp / (fp + tn)

# False Alarm Rate (FAR)
FAR = fn / (fn + tp)

# Gamma calculation
gamma = (tp + fn) / (tn + fp)

# Authentication Rate (AR)
AR = (tp + gamma * tn) / ((tp + fn) + gamma * (tn + fp))

print(f"MDR: {MDR}")
print(f"FAR: {FAR}")
print(f"AR: {AR}")
# Out:
# Classification Accuracy: 56.00%
#
# Total testing channel: (1200,)
# tp: 386
# tn: 286
# fp: 314
# fn: 214
# MDR: 0.5233333333333333
# FAR: 0.3566666666666667
# AR: 0.56
